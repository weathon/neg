# %%
import torch
from diffusers import StableDiffusion3Pipeline

pipe = StableDiffusion3Pipeline.from_pretrained("stabilityai/stable-diffusion-3.5-medium", torch_dtype=torch.bfloat16)
pipe = pipe.to("cuda")
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  2.71it/s]it/s]
# Loading pipeline components...: 100%|██████████| 9/9 [00:02<00:00,  3.44it/s]

# %%
image = pipe(
    "a womrn standing close to the camera",
    negative_prompt="there is hair on her head",
    num_inference_steps=40,
    guidance_scale=10,
).images[0]
image
# Out:
# 100%|██████████| 40/40 [00:27<00:00,  1.48it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>
